# %%
Q1. What are the three measures of central tendency?
The three measures of central tendency are:

Mean: The average of a dataset.
Median: The middle value of a dataset when arranged in ascending order.
Mode: The most frequently occurring value(s) in a dataset.
Q2. What is the difference between the mean, median, and mode? How are they used to measure the central tendency of a dataset?
Mean: The sum of all values divided by the total number of values. It is sensitive to outliers.
Median: The middle value when the data is ordered. It is less affected by outliers.
Mode: The value(s) that occur most frequently. It is useful for categorical data.
They are used as follows:

Mean: Provides a general average, often used in continuous data.
Median: Represents the central point, useful when data is skewed.
Mode: Indicates the most common value, useful in categorical and discrete datasets.
Q3. Measure the three measures of central tendency for the given height data:
Dataset: [178, 177, 176, 177, 178.2, 178, 175, 179, 180, 175, 178.9, 176.2, 177, 172.5, 178, 176.5]

Mean: 
Mean
=
Sum of all values
Number of values
Mean= 
Number of values
Sum of all values
​
 
Median: Arrange data and find the middle value(s).
Mode: Identify the most frequently occurring value(s).
Calculations: Mean 
≈
2847.3
16
=
177.96
≈ 
16
2847.3
​
 =177.96
Median 
=
177
=177
Mode 
=
178
=178

Q4. Find the standard deviation for the given data:
Standard deviation measures the spread of data around the mean.

Steps:

Find the mean (
𝜇
=
177.96
μ=177.96).
Calculate the variance (
𝜎
2
=
∑
(
𝑥
𝑖
−
𝜇
)
2
𝑛
σ 
2
 = 
n
∑(x 
i
​
 −μ) 
2
 
​
 ).
Take the square root of the variance.
Result: The standard deviation 
𝜎
≈
1.98
σ≈1.98.

Q5. How are measures of dispersion such as range, variance, and standard deviation used to describe the spread of a dataset? Provide an example.
Range: Difference between the maximum and minimum values. Indicates overall spread.
Variance: Average of squared differences from the mean. Represents data variability.
Standard Deviation: Square root of variance. Indicates average distance from the mean.
Example: Dataset: [5, 10, 15, 20]

Range: 
20
−
5
=
15
20−5=15
Variance: 
50
4
=
12.5
4
50
​
 =12.5
Standard Deviation: 
12.5
=
3.54
12.5
​
 =3.54
Q6. What is a Venn diagram?
A Venn diagram is a graphical representation of sets, showing their relationships using overlapping circles. Each circle represents a set, and overlaps indicate common elements.

Q7. For the two given sets A = {2, 3, 4, 5, 6, 7} & B = {0, 2, 6, 8, 10}, find:
(i) 
𝐴
∩
𝐵
=
{
2
,
6
}
A∩B={2,6} (common elements)
(ii) 
𝐴
∪
𝐵
=
{
0
,
2
,
3
,
4
,
5
,
6
,
7
,
8
,
10
}
A∪B={0,2,3,4,5,6,7,8,10} (all unique elements)

Q8. What do you understand about skewness in data?
Skewness indicates the asymmetry of a dataset's distribution:

Right-skewed: Tail on the right; mean > median.
Left-skewed: Tail on the left; mean < median.
Q9. If a dataset is right-skewed, what will be the position of the median with respect to the mean?
In a right-skewed dataset, the median is less than the mean.

Q10. Explain the difference between covariance and correlation. How are these measures used in statistical analysis?
Covariance: Measures the degree to which two variables change together. It has units of the variables.
Correlation: Standardized form of covariance, ranging between -1 and 1. Indicates the strength and direction of the relationship.
Usage:

Covariance shows direction (positive or negative).
Correlation quantifies the relationship strength.
Q11. What is the formula for calculating the sample mean? Provide an example calculation for a dataset.
Formula: 
𝑥
ˉ
=
∑
𝑥
𝑖
𝑛
x
ˉ
 = 
n
∑x 
i
​
 
​
 
Example: Dataset = [5, 10, 15] 
𝑥
ˉ
=
5
+
10
+
15
3
=
10
x
ˉ
 = 
3
5+10+15
​
 =10
Q12. For a normal distribution, what is the relationship between its measures of central tendency?
In a normal distribution, mean = median = mode.

Q13. How is covariance different from correlation?
Covariance measures joint variability, while correlation measures the strength and direction of the relationship.
Correlation is dimensionless, whereas covariance depends on the units of the variables.
Q14. How do outliers affect measures of central tendency and dispersion? Provide an example.
Central Tendency: Outliers can significantly affect the mean but have minimal impact on the median and mode.
Dispersion: Outliers increase range, variance, and standard deviation.
Example: Dataset: [10, 20, 30, 1000]

Mean: 
265
265 (inflated by outlier)
Median: 
25
25 (not affected)
Range: 
1000
−
10
=
990
1000−10=990 (increased)
